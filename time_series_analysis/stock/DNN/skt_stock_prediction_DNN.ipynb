# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import os, sys
sys.path.append(os.getcwd()[:os.getcwd().rfind(os.sep)])

# %%
# 유틸함수 사용
from marcap_utils import marcap_date
from marcap_utils import marcap_date_range

# %%
# Out:
# row count: 8480052
#      Code    Name      Close  Changes ChagesRatio     Volume        Amount  \
# 0  022875  평화은행우선  1001000.0      0.0           0        0.0  0.000000e+00
# 1  005930    삼성전자   167500.0   9500.0           6   789127.0  1.297501e+11
# 2  017670   SK텔레콤   260500.0   7500.0           3   138214.0  3.553592e+10
# 3  030200     케이티    67300.0    300.0         0.4   405568.0  2.712890e+10
# 4  015760  한국전력공사    24300.0    700.0           3  1300030.0  3.130251e+10
#
#        Open      High       Low        Marcap  MarcapRatio       Stocks  \
# 0       0.0       0.0       0.0  4.404400e+13       144.34   44000000.0
# 1  158000.0  169000.0  157000.0  2.533269e+13        83.02  151239942.0
# 2  253000.0  261500.0  250000.0  2.322427e+13        76.11   89152670.0
# 3   66800.0   67800.0   66000.0  2.101104e+13        68.86  312199659.0
# 4   24000.0   24450.0   23600.0  1.555445e+13        50.97  640100876.0
#
#    ForeignShares  ForeignRatio  Rank       Date
# ...

# %%
# SKT(017670), 시가총액 비중의 변화
#df = marcap_date_range('2001-01-01', '2018-11-15', targetFolder = '../data')
code = '017670'
df_stock = marcap_date_range('2001-01-01', '2018-11-15', code, targetFolder = '../data')

print('row count:', len(df_stock))
df.head()

df_stock['MarcapRatio'].plot(figsize=(16, 6))
# Out:
# row count: 4408

# %%
df_stock['Marcap'].plot(figsize=(16, 6))

# %%
print (len(df_stock['Close']))
df_stock['Close'].plot(figsize=(16, 6))
# Out:
# 4408
